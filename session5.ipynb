# %%
pi=3.14
r=100
area=pi*r*r
print(f" area of circle : {area}")
# Out:
#  area of circle : 31400.0

# %%
3**2, 3**3, 3**4
# Out:
# (9, 27, 81)

# %%
height=10
breadth=20
area=0.5*height*breadth
print(f"area of triangle: {area}")
# Out:
# area of triangle: 100.0

# %%
n1=20
n2=30
n3=40
avg=(n1+n2+n3)/3
avg
# Out:
# 30.0

# %%
round(31.66)
# Out:
# 32

# %%
round(31.66, 1)
round(31.66,2)
# Out:
# 31.66

# %%
round(31.867,2)
# Out:
# 31.87

# %%
round(10.5787,3)
# Out:
# 10.579

# %%
round(11.453,3)
# Out:
# 11.453

# %%
round(11.554,3)
# Out:
# 11.554

# %%
n1=25
n2=30
n3=40
avg=round((n1+n2+n3)/3,2)
avg
# Out:
# 31.67

# %%
bill_amount=1000
tip_per=10
tip_amount=bill_amount*tip_per/100
print(f"tip_amount:{tip_amount}")
total_bill=bill_amount+ tip_amount
print("the total bill is:", total_bill)
# Out:
# tip_amount:100.0
# the total bill is: 1100.0

# %%
salary=100000
tax_percentage=10
tax_pay=salary*tax_percentage/100
net_pay=salary-tax_pay
#net_pay
print(f"tax_pay is:{tax_pay} net_pay:{net")
# Out:
# tax_pay is:10000.0

# %%
weight_in_kg=60
one_kg_in_pounds=2.2
total_weight_in_pounds=weight_in_kg * one_kg_in_pounds
print(f"for {weight_in_kg}kgs the weight in pounds is {total_weight_in_pounds}pounds")
print(f"for 60kgs the weight in pounds is 132 pounds")
# Out:
# for 60kgs the weight in pounds is 132.0pounds
# for 60kgs the weight in pounds is 132 pounds
