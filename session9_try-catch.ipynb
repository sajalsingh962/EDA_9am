# %% [markdown]
# - try and except is used to catch the errir
# -
# -

# %%
import os
os.makdirs('try')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 os.makdirs('try')
#
# AttributeError: module 'os' has no attribute 'makdirs'

# %%
0/10
# Out:
# 0.0

# %% [markdown]
# - zero division error

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
import random
random.virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 import random
# ----> 2 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
int('10.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 int('10.4')
#
# ValueError: invalid literal for int() with base 10: '10.4'

# %% [markdown]
# - Name Error
# - Type Error
# - value Error
# - Module not found error
# - attribute error
# - Zero division error

# %%
try:
    a=10
    b=20
    c=a+b
    
    print(f'the addition of {a} and {b} is :{c}')
except:
        print('Hello bro error agaya thats Im agaya')
# Out:
# the addition of 10 and 20 is :30

# %%
try:
    a=10
    b=0
    print(b)
except:
    print('error agaya that's why I came')
# Out:
#   Cell In[19], line 6
#     print('error agaya that's why I came')
#                                         ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
try: 
    num1=eval(input('enter the number1: '))
    num2=eval(input('enter the number2: '))
    avg=(num1+num2)/0
    print(f'the average of{num1} and {num2} is:{avg}')
except Exception as e: 
    print(e)
    # print(' ha ha')
# Out:
# enter the number1:  10
# enter the number2:  10
# division by zero

# %%
try:
    omkar
except Exception as e:
    print(e)
# Out:
# name 'omkar' is not defined

# %%
try:
    omkar
except Exception:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 try:
# ----> 2     omkar
#       3 except Exception:
#
# NameError: name 'omkar' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       2     omkar
#       3 except Exception:
# ----> 4     print(e)
#
# NameError: name 'e' is not defined

# %%
try: 
    try:
        num=eval(input('enter number: '))
    except Exception as teja:
        print(teja)
    if num%2==0:
        print(f'the {num} is an even')
    else:
        print(f'the {num} is an odd')
except Exception as e:
    print(e)
# Out:
# enter number:  1z
# invalid decimal literal (<string>, line 1)
# the 10 is an even

# %%
try:
    a=10
    b=20
    c=a+b
    print(f'the addition of {a} and {b} is: {c}')
except: 
    print('Hello bro error agay thats Im agaya')
finally:
    print('bye')
# Out:
# the addition of 10 and 20 is: 30
# bye
