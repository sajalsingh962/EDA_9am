# %%
file_path='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
print(file_path)

file=open(file_path)
# dir(file)

# data=file.read()

# data
# for i in data.split('\n'):
#     print(i)
# Out:
# /Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt

# %% [markdown]
# - File name
# - is the file availbe in the direcotry or not
# - if anything is wrong we will

# %%
print('operation completed...')
# Out:
# operation completed...

# %%
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
file_location
file=open(file_location)
data=file.read()
print(data[:5])

with open(file_location) as file:
    data=file.read()
    print(data[:5])
# Out:
# ﻿From
# ﻿From

# %%
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
file=open(file_location)
data=file.read()
# for i in data:
    # print(i)
# Out:
#   Cell In[33], line 5
#     # print(i)
#               ^
# _IncompleteInputError: incomplete input

# %%
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
with open(file_location) as file:
    for i in enumerate(file):
        # print(i)
# Out:
#   Cell In[63], line 4
#     # print(i)
#               ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# - Enumerate will give id: index of sentence and sentence

# %% [markdown]
# - Enumerate gives - Index of sentences and sentences

# %%
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
with open(file_location) as file:
    # for i in enumerate(file):
    #     print(i)
# Out:
#   Cell In[64], line 4
#     #     print(i)
#                   ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# - align the content to left
# - String method - strip

# %%
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
with open(file_location) as file:
    for i,j in enumerate(file):
         # print(j)
         if(j.startswith('From')): 
             # print(j)
# Out:
#   Cell In[66], line 6
#     # print(j)
#               ^
# _IncompleteInputError: incomplete input

# %%
# no of lines
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
with open(file_location) as file:
    for i,j in enumerate(file):
        pass
i
# Out:
# 2124

# %%
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
with open(file_location):
    for i,j in enumerate(file):
        print(j.strip())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 3
#       1 file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
#       2 with open(file_location):
# ----> 3     for i,j in enumerate(file):
#       4         print(j.strip())
#
# ValueError: I/O operation on closed file.

# %%
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
with open(file_location) as file:
    for i,j in enumerate(file):
        if j.startswith('From'):
            print(j)
# Out:
# From: stephen.marquard@uct.ac.za
#
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
#
# From: louis@media.berkeley.edu
#
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
#
# From: zqian@umich.edu
#
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
#
# From: rjlowe@iupui.edu
#
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
#
# From: zqian@umich.edu
#
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
#
# From: rjlowe@iupui.edu
#
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
#
# From: cwen@iupui.edu
#
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
#
# From: cwen@iupui.edu
#
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
#
# From: gsilver@umich.edu
#
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
#
# From: gsilver@umich.edu
#
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
#
# From: zqian@umich.edu
#
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
#
# From: gsilver@umich.edu
#
# From wagnermr@iupui.edu Fri Jan  4 10:38:42 2008
#
# From: wagnermr@iupui.edu
#
# ...

# %%
list_l1=[]
with open(file_location) as file:
    for i,j in enumerate(file):
        if j.startswith('From'):
            list_l1.append(j)
list_l1
# Out:
# ['From: stephen.marquard@uct.ac.za\n',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008\n',
#  'From: louis@media.berkeley.edu\n',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008\n',
#  'From: zqian@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008\n',
#  'From: gsilver@umich.edu\n',
# ...

# %%
l1=[]
with open(file_location) as file:
    for i,j in enumerate(file):
        if j.startswith('From'):
            l1.append(j.replace('\n', ''))
# l1

# %%
#Q5
l1=[]
file_location='/Users/suniltomar/Desktop/workspace/Gen_AI/Data_files/mbox-short.txt'
with open(file_location) as file:
    for i,j in enumerate(file):
        if j.startswith('From'):
            l1.append(j.replace('\n', ''))
# l1

#extract emails
for i in l1:
    if i.contains('@'):
        print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[103], line 12
#       8 # l1
#       9
#      10 #extract emails
#      11 for i in l1:
# ---> 12     if i.contains('@'):
#      13         print(i)
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
str1='ssss'
dir(str1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...
