# %%
l=['hyd', 'bengaluru', 'pune', 'mumbai']
[i.capitalize() for i in l]
# Out:
# ['Hyd', 'Bengaluru', 'Pune', 'Mumbai']

# %%
l=['hyd', 'bengaluru', 'pune', 'mumbai']
op=lambda i: i.capitalize() 
[op for i in l]

lambda i:i.capitalize()
# Out:
# <function __main__.<lambda>(i)>

# %%
add = lambda a,b: a+b
add(10,20)
# Out:
# 30

# %%
f1=lambda i:i.capitalize()

# %%
l=['hyd', 'bengaluru', 'pune', 'mumbai']
print(type(l))
print(type(lambda i: i.capitalize()))
obj=lambda i: i.capitalize(),l
print(type(obj))
print(obj)
print(type(map(lambda i:i.capitalize(),l)))

# [obj]
# Out:
# <class 'list'>
# <class 'function'>
# <class 'tuple'>
# (<function <lambda> at 0x127037100>, ['hyd', 'bengaluru', 'pune', 'mumbai'])
# <class 'map'>
# [(<function __main__.<lambda>(i)>, ['hyd', 'bengaluru', 'pune', 'mumbai'])]

# %%
lambda i: i.capitalize()
print(type(lambda))
# Out:
#   Cell In[17], line 2
#     print(type(lambda))
#                      ^
# SyntaxError: invalid syntax

# %%
l=['hyd', 'benga#luru', 'pune', 'mum#bai']
#extract wala 
op=lambda i: i if '#' in i else '',l
[i if '#' in i else None for i in l]

#argument : i 
# expression: '#' in i
# True or False in only the expression
# Out:
# [None, 'benga#luru', None, 'mum#bai']

# %%
l=['hyd', 'benga#luru', 'pune', 'mum#bai']
lambda i: '#' in i
lambda i: '#' in i, l
map(lambda i: '#' in i, l)
list(map(lambda i: '#' in i, l))
# Out:
# [False, True, False, True]

# %%
l=['hyd', 'benga#luru', 'pune', 'mum#bai']
lambda i: '#' in i
lambda i: '#' in i, l
filter(lambda i: '#' in i,l)
list(filter(lambda i: '#' in i,l))
# Out:
# ['benga#luru', 'mum#bai']

# %%
l=['1,4,9,16']
#wap get the square of each element
lambda i: i*i,l
map(lambda i: i*i,l)
# list(filter( lambda i:i*i, l))

# %%
from functools import reduce

numbers = [1, 2, 3, 4, 5]

result = reduce(lambda a, b: a + b, numbers)
print(result)  # Output: 15
# Out:
# 15

# %%
from functools import reduce
numbers = [1,2,3,4,5]
result= reduce(lambda a,b: a+b, numbers)
result
# Out:
# 15

# %%
from functools import reduce
numbers = [1,2,3,4,5]
result = reduce(lambda a,b:a+b, numbers)
result
# Out:
# 15

# %% [markdown]
# - $Dictionaries

# %%
names=['Ramesh', 'Suresh', 'Mahesh']
age=[20, 22, 24]

for i in range(0,len(names)):
    print(f'{names[i]} age is {age[i]}')
# Out:
# Ramesh age is 20
# Suresh age is 22
# Mahesh age is 24

# %%
# names[0] age is age[0]
# names[1] age is age[1]
# names[2] age is age[2]
names[0]
age[0]
# Out:
# 20

# %%
l1=[10,20,30]
l2=[1,2,3]
l=[11,22,33]

for i in range(len(l1)):
    l[i]=l1[i]+l2[i]
l


[i+j for i,j in ranges(l1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 10
#       6     l[i]=l1[i]+l2[i]
#       7 l
# ---> 10 [i+j for i,j in ranges(l1)]
#
# NameError: name 'ranges' is not defined

# %%
name='ramesh'
age='20'
list(zip(name,age))
# Out:
# [('r', '2'), ('a', '0')]

# %%
names=['Ramesh', 'Suresh', 'Mahesh']
age=[20, 22, 24]

list(zip(names, age))

for i,j in zip(names, age):
    print(i,j)
# Out:
# Ramesh 20
# Suresh 22
# Mahesh 24

# %% [markdown]
# - Zip

# %%
names,age
# Out:
# (['Ramesh', 'Suresh', 'Mahesh'], [20, 22, 24])

# %%
zip(names, age)

# %%
list(zip(names,age))
# Out:
# [('Ramesh', 20), ('Suresh', 22), ('Mahesh', 24)]

# %%
for i in zip(names,age):
    print(i)
    print(type(i))
# Out:
# ('Ramesh', 20)
# <class 'tuple'>
# ('Suresh', 22)
# <class 'tuple'>
# ('Mahesh', 24)
# <class 'tuple'>

# %% [markdown]
# - zip is mainly used for both lists have same length
# - if you want different length you can use it

# %%
l1=[10,20,30]
l2=['A', 'B' ]

for i in zip(l1,l2):
    print(i)
# Out:
# (10, 'A')
# (20, 'B')

# %%
l1=[10,20,30,40]
l2=[1,2,3]

# l=[11,22,33,40]
l=[]

for i,j in zip(l1,l2):
    print(i+j)
    l.append(i+j)
# Out:
# 11
# 22
# 33

# %%
l1=[10,20,30,40]
l2=[1,2,3]
l=[]

# for i in range(len(l1)):
#     if i<len(l2):
#         print(i)
#     else:
#         print(i)


# max_len=len(l1)>len(l2) ? len(l1):len(l2)
for i in range(5):
    if i<len(l1):
        print(l1[i])
        if i<len(l2):
            l.append(l1[i]+l2[i])
        else:
            
    else:
        print('out of range')
l
# Out:
# 10
# 20
# 30
# 40
# out of range
# [11, 22, 33]

# %% [markdown]
# - zip means combine the two elements which are have some
# - Ramesh is realted with 20
# - suresh is realted with 22
# - these related values we can form a dictionary
# - dictionary is a key-value pair
# - represnt with {}
# - {key:value}
# - assume ramesh is key and 20 is value : {Ramesh:20}

# %%
d1={'Ramesh':20, 'Suresh':22, 'Mahesh':24}
d1
# Out:
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24}

# %%
d2={20:'Ramesh', 22:'Suresh', 24:'Mahesh'}
d2
# Out:
# {20: 'Ramesh', 22: 'Suresh', 24: 'Mahesh'}

# %%
d1={'key':'value'}
type(d1)
dict d
# Out:
# dict

# %%
d1={'Ramesh': 20, 'Ramesh':22}
d1
# Out:
# {'Ramesh': 22}

# %%
dict5={'Ramesh': 20, 'Ramesh':22}
dict5
# Out:
# {'Ramesh': 22}

# %%
#Dulicates
dict6={'Ramesh': 20, 'Ramesh': 20,}
dict6

#dulicate not allwed on key
# Out:
# {'Ramesh': 20}

# %%
#keys can not be dulicate but value can.
dict7={'Ramesh': 20, 'Suresh': 20}
dict7
# Out:
# {'Ramesh': 20, 'Suresh': 20}

# %% [markdown]
# **IN DICTIONARY KEYS ARE IMPORTANT**

# %% [markdown]
# **IN DICTIONALY KEYS ARE IMPORTANT**

# %%
#HETRO GENIOUS
dict8={'Ramesh':20,
         20:'Suresh',
      True: False,
       (''):''
      }
dict8
# Out:
# {'Ramesh': 20, 20: 'Suresh', True: False}

# %%
dict9={'Names': ['Ramesh', 'Suresh', 'Mahesh']}
dict9={'':[]}
dict9={'Frut':[]}

# %%
#list as key
dict12={['Ramesh', 'Suresh', 'Mahesh']: 'names'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[133], line 2
#       1 #list as key
# ----> 2 dict12={['Ramesh', 'Suresh', 'Mahesh']: 'names'}
#
# TypeError: unhashable type: 'list'

# %%
#tuple as key
dict12={('Ramesh', 'Suresh', 'Mahesh'): 'names'}
dict12
# Out:
# {('Ramesh', 'Suresh', 'Mahesh'): 'names'}

# %% [markdown]
# - dictionary in build fuctions
# - max, min, len,sum sorted, reversed

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':20,'Ganesh':20,}
print(dict1, 'max:', max(dict1), 'min:',min(dict1))
# Out:
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 20, 'Ganesh': 20} max: Suresh min: Ganesh

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':20,'Ganesh':20,}
sum(dict1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 dict1={'Ramesh':20,'Suresh':22,'Mahesh':20,'Ganesh':20,}
# ----> 2 sum(dict1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
dict2={24: 'Ramesh',21: 'Suresh',22: 'Ganesh',}
sum(dict2)
# Out:
# 67

# %%
dict2={24: 'Ramesh',21: 'Suresh',22: 'Ganesh',}

sorted(dict2)
# Out:
# [21, 22, 24]

# %%
dict2={24: 'Ramesh',21: 'Suresh',22: 'Ganesh',}
reversed(dict2)
dict2
# Out:
# {24: 'Ramesh', 21: 'Suresh', 22: 'Ganesh'}

# %%
dict2[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dict2[1]
#
# KeyError: 1

# %%
dict1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dict1[0]
#
# KeyError: 0

# %% [markdown]
# -  we can not extract element using indexing

# %% [markdown]
# - we can not extracg element usign idexing
# -

# %%
# 'Ramesh':20  key:value
# 'Suresh': 22
# 'Maehsh': 24
# we can extract only values by using key
dict1={'Ramesh':20 , 'Suresh': 22, 'Mahesh': 24 }

dict1['Ramesh'], dict1['Suresh'], dict1['Mahesh']
# Out:
# (20, 22, 24)

# %%
d={}
d['Ramesh']=20
d['Suresh']=22
d['Mahesh']=24
d
# Out:
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24}

# %%
names=['Ramesh', 'Suresh', 'Mahesh']
age=[20,22,24]

names,age
# Out:
# (['Ramesh', 'Suresh', 'Mahesh'], [20, 22, 24])

# %%
names=['Ramesh', 'Suresh', 'Mahesh', 'Ganesh']
age=[20,22,24,26]

d={}
print(d)
for i,j in zip(names,age):
    d[i]=j
d
# Out:
# {}
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24, 'Ganesh': 26}

# %%
numbers=[20,21,22]
d={}
for i in numbers:
    if i%2==0:
        d[i]='even'
    else:
        d[i]='odd'

d
# Out:
# {20: 'even', 21: 'odd', 22: 'even'}

# %%
numbers={2,5,7,6,4,2,3}
dd={}
for i in numbers:
    if i%2==0:
        dd[i]='even'
    else:
        dd[i]='odd'
dd
# Out:
# {2: 'even', 3: 'odd', 4: 'even', 5: 'odd', 6: 'even', 7: 'odd'}

# %%
names=['Ram','Ramesh', 'Suresh', 'Mahesh', 'Ganesh']
age=[10, 20,22,24,28]
{i:j for i,j in zip(names, age)}
# Out:
# {'Ram': 10, 'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24, 'Ganesh': 28}

# %%
dd={'Fruites': ['Apple', 'Banana', 'Cherry']}
dd
# Out:
# {'Fruites': ['Apple', 'Banana', 'Cherry']}

# %%
d={'Fruites': {'Apple': ['Kashmir']}}
d['Fruites']['Apple'][0]
# Out:
# 'Kashmir'

# %%
d={'Fruites': [{'Apple': ['green apple']}]}
d
# Out:
# {'Fruites': [{'Apple': ['green apple']}]}

# %%
d={'Fruites': [{'Apple':['green apple']}]}
d['Fruites'][0]['Apple'][0]
# Out:
# 'green apple'

# %%
d={'Fruites': [{'Apple': [{'kashmir': [{'India': ['NareshIT']}]}]}] }
d['Fruites'][0]['Apple'][0]['kashmir'][0]['India'][0]
dir(d)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
'clear', # dic clear 
'copy',
'fromkeys',
'get',
'items',
 'keys',
 'pop',
 'popitem',#delete item
 'setdefault',
 'update', #l1.extend(l2)
 'values' # only values
# Out:
#   Cell In[81], line 2
#     'copy',
#     ^
# IndentationError: unexpected indent
