# %% [markdown]
# - Numpy
# - Repreentation of elements or number we can do following way
# - - List
#   - tuple
#   - array
#   - tensor
# - list and tuple very base level representation
# - whenvever if anyone say **array** means we need to recall **numpy**
# - whenever if anyone say **tensor** means we need to recall **tensorflow and
#
# - whenever if anyone
#
# -

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.1.3'

# %% [markdown]
# # Create an array

# %%
l=[1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
np.array(l)
# Out:
# array([1, 2, 3, 4])

# %%
l1=[10,20,30,40]
l2=[100,200,300,400]

#l=[110,220,330,440]
l=[i+j for i,j in zip(l1,l2)]
l
# Out:
# [110, 220, 330, 440]

# %%
l=[i+j for i,j in zip(l1,l2)]
# for i,j in zip(l1,l2):
#     l.append(i+j)

l
# Out:
# [110, 220, 330, 440]

# %%
arr1=np.array(l1)
arr2=np.array(l2)
arr1+arr2
# Out:
# array([110, 220, 330, 440])

# %%
arr1*arr2
# Out:
# array([ 1000,  4000,  9000, 16000])

# %%
arr1/arr2
# Out:
# array([0.1, 0.1, 0.1, 0.1])

# %%
arr2/arr1
# Out:
# array([10., 10., 10., 10.])

# %%
import time
start=time.time()
l1=list(range(1, 10000000))
l2=list(range(1, 10000000))
l=[i*j for i,j in zip(l1,l2)]
end=time.time()

print(f'time taken is:{end-start} ms')

# %%
import numpy as np
l1=[10,20,30,40]
l2=[1,2,3,4]
# np.array(object,dtype)
np.array(l1)
np.array(l2)
# Out:
# array([1, 2, 3, 4])

# %%
import random
random.randint(1,3)
# Out:
# 1

# %%
random.randint(1,1000)
random.randint(1,100,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 random.randint(1,1000)
# ----> 2 random.randint(1,100,10)
#
# TypeError: Random.randint() takes 3 positional arguments but 4 were given

# %%
import numpy as np
np.random.randint(1,100)
# Out:
# 45

# %%
print(np.random.randint(1))
print(np.random.randint(1,100,9))

print('====')
shape=(3,3)
print(np.random.randint(1,10,shape))
# Out:
# 0
# [10 53 47 10 72 93 87 88 74]
# ====
# [[7 4 6]
#  [9 5 3]
#  [7 3 4]]

# %% [markdown]
# **np.random.random**

# %% [markdown]
# **np.random.random**

# %%
random.random()
# Out:
# 0.0903782413582469

# %% [markdown]
# - random.randint ===> np.random.randint
# - random.random ===> np.random.random

# %%
np.random.random(size=10)
# Out:
# array([0.9362537 , 0.05613952, 0.13846897, 0.30498558, 0.46256722,
#        0.12965235, 0.42440551, 0.84272491, 0.9106114 , 0.51012784])

# %%
np.random.random(size=(2,2))
# Out:
# array([[0.12546757, 0.7130762 ],
#        [0.42628055, 0.72386711]])

# %%
np.random.rand(2,2)
# Out:
# array([[0.86311807, 0.1609372 ],
#        [0.58708562, 0.36566583]])

# %%
np.random.rand(10)
# Out:
# array([0.29573062, 0.78752458, 0.06988634, 0.69006396, 0.99718428,
#        0.93742872, 0.95640447, 0.925415  , 0.90522119, 0.94036086])

# %%
np.random.randn(5) # standard normal
# Out:
# array([ 1.01406948,  1.28738746, -0.33723224, -0.09507183,  0.79067971])

# %% [markdown]
# - random.randint === np.random.randint
# - random.random === np.random.random
# - random.choice === np.random.choice

# %%
l=range(1,10)
random.choice(l)
# Out:
# 9

# %%
l=list(range(1,10))
random.choice(l)
# Out:
# 3

# %% [markdown]
# - np.random.choice

# %%
data=np.random.normal(100,3,100)

np.mean(data), np.std(data)
# Out:
# (np.float64(100.11442160164196), np.float64(2.8613968326469656))

# %%
import matplotlib.pyplot as plt
plt.hist(data)
# Out:
# (array([ 1.,  1.,  5.,  8., 17., 20., 22., 16.,  8.,  2.]),
#  array([ 90.87833162,  92.5573399 ,  94.23634818,  95.91535645,
#          97.59436473,  99.27337301, 100.95238128, 102.63138956,
#         104.31039783, 105.98940611, 107.66841439]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - exponential

# %%
# data=np.random.normal(100,3,100)

# np.mean(data), np.std(data)

# %%
data_exp=np.random.exponential(2,100)
data_exp
# Out:
# array([1.59106169e-02, 9.46234260e-01, 8.08604409e-01, 2.91956444e+00,
#        1.01683170e+00, 2.01970003e+00, 9.60200989e-01, 1.02682463e+00,
#        6.34725143e+00, 1.64059699e+00, 9.53471470e-01, 2.98414203e-01,
#        6.56151017e+00, 1.12857934e+00, 1.70228664e+00, 3.36452382e-01,
#        7.81753722e-02, 2.25759426e-01, 2.04795930e-01, 1.22769510e+01,
#        9.14289122e-01, 9.75587412e-01, 9.21032407e-01, 2.46833788e+00,
#        1.56370634e+00, 3.74840852e-01, 1.69108489e-03, 4.02984813e-01,
#        1.70189076e+00, 1.93340366e+00, 1.11073102e+00, 5.76096686e+00,
#        6.14910163e+00, 1.42954731e+00, 2.17169460e+00, 3.83884135e-01,
#        5.52500095e-01, 9.81795270e-02, 3.44375646e+00, 5.17324467e-01,
#        1.67281755e+00, 4.33938137e-01, 6.87842458e-01, 3.30888776e+00,
#        1.51144329e+00, 6.52156991e-02, 1.16086595e+00, 2.48868665e+00,
#        3.10761936e+00, 1.16081786e+00, 6.88456855e-01, 4.44515747e+00,
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(data_exp)
# Out:
# (array([52., 21., 12.,  6.,  5.,  3.,  0.,  0.,  0.,  1.]),
#  array([1.69108489e-03, 1.22921707e+00, 2.45674306e+00, 3.68426905e+00,
#         4.91179504e+00, 6.13932103e+00, 7.36684702e+00, 8.59437300e+00,
#         9.82189899e+00, 1.10494250e+01, 1.22769510e+01]),
#  <BarContainer object of 10 artists>)

# %%
plt.show(data)

# %% [markdown]
# - np.zeros
# - np.ones
# - np.full
# - np.eye

# %% [markdown]
# - step-1: pip unistall numpy
# - step-2: jupiter notebook run the command
# -         import numpy as np
# -         error: module numpy not found
# -          if error not comes restart kernel
# -  step-3: pip install numpy==1.26.4
# -  step-4: 100% restart the kernel

# %%
np.__version__
# Out:
# '1.26.4'

# %%
# pip uninstall numpy
# Out:
# WARNING: Skipping numpy as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %% [markdown]
# - min
# - max
# - mean
# - median
# - mode
# -
# - standard deviagtion
# - covariance
# - min max scalar

# %%
data=np.random.randn(1,10,2)
data
# Out:
# array([[[-0.14979924, -0.45385687],
#         [ 1.50813134,  1.37447248],
#         [-0.05286384, -1.51041721],
#         [ 0.81111194,  0.29294478],
#         [-0.7427697 ,  0.39894609],
#         [ 0.56489102,  1.14106084],
#         [-2.42664431,  0.95323309],
#         [-0.66961334,  0.47777939],
#         [ 0.25593052, -1.45903529],
#         [-0.14167564, -2.05285269]]])

# %%
data.min(),data.max()
# Out:
# (-2.4266443137544496, 1.508131338305218)

# %%
data.mean()
# Out:
# -0.09405133383249399

# %%
data.median(), data.mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data.median(), data.mode()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
data.var()
# Out:
# 1.173873984730449

# %%
data.std()
# Out:
# 1.083454652826065

# %%
# dir(data)

# %%
data.cov()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data.cov()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cov'

# %% [markdown]
# - Euclidain distance
# - cosine distance

# %%
import numpy as np
# xi means array
l=list(range(1,100))
l
arr1=data=np.random.randn(1,10)
mean=arr1.mean()

# arr2=arr1-mean
arr2=arr1-np.mean(arr1)

arr2

res=np.square(arr1-np.mean(arr1))
res

res=(np.sum(np,square(arr1-np.mean(arr1)))/np.count_nonzero(arr1)(arr1))
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 16
#      13 res=np.square(arr1-np.mean(arr1))
#      14 res
# ---> 16 res=(np.sum(np,square(arr1-np.mean(arr1)))/np.count_nonzero(arr1)(arr1))
#      17 res
#
# NameError: name 'square' is not defined

# %%
np.sqrt(np.sum(arr1))
# Out:
# /var/folders/_k/nb8df8n930bgt43cftlbg_qw0000gn/T/ipykernel_8247/1495390204.py:1: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(np.sum(arr1))
# nan

# %%
xi=range(1,11)
yi=range(100,110)

xi_diff=(xi - np.mean(xi))
yi_diff=(yi - np.mean(yi))        
n=np.count_nonzero(xi)

res=np.sqrt(xi_diff * yi_diff)/n-1

res


# len(xi),len(yi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       1 xi=range(1,11)
#       2 yi=range(100,110)
# ----> 4 xi_diff=(xi - np.mean(xi))
#       5 yi_diff=(yi - np.mean(yi))
#       6 n=np.count_nonzero(xi)
#
# File /opt/anaconda3/lib/python3.13/site-packages/numpy/core/_methods.py:106, in _mean(a, axis, dtype, out, keepdims, where)
#     102 arr = asanyarray(a)
#     104 is_float16_result = False
# --> 106 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     107 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     108     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File /opt/anaconda3/lib/python3.13/site-packages/numpy/core/_methods.py:77, in _count_reduce_items(arr, axis, keepdims, where)
#      75     items = 1
#      76     for ax in axis:
# ...

# %%
import numpy as np
# np

x=range(1,11)
y=range(100,110)

arr1=np.array(x)
arr1_mean=np.mean(arr1)
arr11=arr1-arr1_mean
arr11
###
arr2=np.array(y)
arr2_mean=np.mean(arr2)
arr22=arr2-arr2_mean
# ##########
arr3=arr11 * arr22
# ###########
arr4=np.sum(arr3)
arr4/10
# Out:
# 8.25

# %%
arr1=np.array(x)
arr2=np.array(y)
np.sum((arr1-np.mean(arr1))*(arr2-np.mean(arr2)))/
# Out:
#   Cell In[51], line 3
#     np.sum((arr1-np.mean(arr1))*(arr2-np.mean(arr2)))/
#                                                       ^
# SyntaxError: invalid syntax

# %%
arr1=np.array(x)
arr1_mean=np.mean(arr1)
arr11=arr1-arr1_mean #diff = x-xi

arr2=np.array(y)
arr2_mean=np.mean(arr2)
arr12=arr2-arr2_mean # diff = y-yi

NR=np.sum(arr11*arr22)   #sum & square

a=np.sum(np.square(arr11))
b=np.sum(np.square(arr22))

# DR=

# %% [markdown]
# - Euclidain Distance
#
# <img id="dimg_ijwlabnmBoLaseMP7L3ciQk_15" src="data:image/png;base64,..." style="object-position:71% 75%" alt="Calculate Euclidean distance in Python ..." class="YQ4gaf" height="162" width="311" data-csiid="ijwlabnmBoLaseMP7L3ciQk_11" data-atf="5">

# %%
x=(10,20)
y=(5,6)

arr1=np.array(x)
arr2=np.array(y)
arr1-arr2  #(x1-x2) && (y1 -y2)

# np.sqrt((x)+(y)
np.sqrt(np.sum(np.square(arr1-arr2)))
# Out:
# 14.866068747318506

# %% [markdown]
# ** Cosine similarity ***
#
#
# <img id="dimg_UjwladbCLo-TseMP4YyGgAQ_21" src="data:image/png;base64,..." style="object-position:0% 44%" alt="Cosine similarity: How does it measure ..." class="YQ4gaf" height="134" width="376" data-csiid="UjwladbCLo-TseMP4YyGgAQ_18" data-atf="1">

# %% [markdown]
# **Cosine similarity***

# %%
x=[1,2,3]
y=[4,5,6]
# convert into array
# NR=np.dont()
# dr=a*b
# a=norm(arr1)

# %%
arr1=np.array(x)
arr2=np.array(y)

NR=np.dot(arr1*arr2)

DR=arr1*arr2

norm_A=norm(arr1)
norm_B=norm(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 4
#       1 arr1=np.array(x)
#       2 arr2=np.array(y)
# ----> 4 NR=np.dot(arr1*arr2)
#       6 DR=arr1*arr2
#       8 norm_A=norm(arr1)
#
# TypeError: dot() missing 1 required positional argument: 'b'
