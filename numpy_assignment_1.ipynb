# %% [markdown]
# 1. Covariance
# Cov
# (
# X
# ,
# Y
# )
# =
# ∑
# (
# x
# i
# −
# x
# ˉ
# )
# (
# y
# i
# −
# y
# ˉ
# )
# n
# Cov(X,Y)=
# n
# ∑(x
# i
# ​
#  −
# x
# ˉ
#  )(y
# i
# ​
#  −
# y
# ˉ
# ​
#  )
# ​

# %%
import numpy as np



#covirance
x=range(1,10)
y=range(10,100)

arr1=np.array(x)
x_mean=arr1.mean()
arr11=arr1-x_mean #diff x-xi


arr2=np.array(y)
y_mean=arr2.mean()
arr22=arr2-y_mean #diff y-yi

##########
arr3=arr11*arr22 

#############
arr4=np.sum(arr3)
arr4/np.count_nonzero(arr11)-1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 19
#      16 arr22=arr2-y_mean #diff y-yi
#      18 ##########
# ---> 19 arr3=arr11*arr22
#      21 #############
#      22 arr4=np.sum(arr3)
#
# ValueError: operands could not be broadcast together with shapes (9,) (90,)
