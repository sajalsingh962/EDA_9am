# %%
a=10

# %%
b=20
c=a+b
c

# %%
c=10
c
# Out:
# 10

# %%
a=10

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %% [markdown]
# hi

# %%
a=10
a
# Out:
# 10

# %% [markdown]
# a=10
# a
#
# esc+m
# esc+y

# %% [markdown]
# - we  develop the project
#
# - we need to create a document for client
#
# - jupiter notebook will give flexibility
#
# - we can write the explaination of each code line
#
# - we can insert diagrams
#
# - we can insert formulae
#
# - we can write bullet points
#
# - we can create a tables
#
# - esc+m ===> shift+enter

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# **python**

# %% [markdown]
# # image will work for some students
# # image
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1200px; height: 320px; margin: 0px; width: 320px;" alt="Python (programming language) - Wikipedia" jsname="kn3ccd">

# %% [markdown]
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20240319155102/what-is-ai-artificial-intelligence.webp" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1000px; height: 150px; margin: 0px; width: 319px;" alt="What is AI? - GeeksforGeeks" jsname="kn3ccd">

# %%
num=100
# 100 is store in a variable called as numm
num
# Out:
# 100

# %%
n1=10
n2=20
n1
n2 # we can able to see only last answer if we are not using print
# Out:
# 20
