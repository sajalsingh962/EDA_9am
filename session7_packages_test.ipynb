# %%
# import random
# import time
random.random()
# Out:
# 0.08469742580953532

# %%
time.sleep(1)
print('sleep for 1 sec')
# Out:
# sleep for 1 sec

# %%
time.sleep(5)
print('hello')
# for i 1 to 10:
#     print('waiting for kernel to wakeup i:',i)
# Out:
# hello

# %%
start=time.time()
time.sleep(5)
end=time.time()
end-start
# Out:
# 5.0053870677948

# %%
start=time.time()
time.sleep(5)
end=time.time()
print(f'the time taken is:{end-start}')
# Out:
# the time taken is:5.0054168701171875

# %%
# module name: keyword
# attribute: kwlist
# import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
random
# Out:
# <module 'random' from '/opt/anaconda3/lib/python3.13/random.py'>

# %%
pip freeze
# Out:
# aext-assistant @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_d5fxz3l2ix/croot/aext-assistant_1746560160060/work
# aext-assistant-server @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_1emcn1_yt0/croot/aext-assistant-server_1746552985810/work
# aext-core @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_2eg8ig5bzd/croot/aext-core_1746546095117/work
# aext-core-server @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_1eo4dumd8o/croot/aext-core-server_1746542359934/work
# aext-panels @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_88neb0jwio/croot/aext-panels_1746560092300/work
# aext-panels-server @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_f8jcm1930j/croot/aext-panels-server_1746552964188/work
# ...

# %%
pip freeze
# Out:
# aext-assistant @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_d5fxz3l2ix/croot/aext-assistant_1746560160060/work
# aext-assistant-server @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_1emcn1_yt0/croot/aext-assistant-server_1746552985810/work
# aext-core @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_2eg8ig5bzd/croot/aext-core_1746546095117/work
# aext-core-server @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_1eo4dumd8o/croot/aext-core-server_1746542359934/work
# aext-panels @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_88neb0jwio/croot/aext-panels_1746560092300/work
# aext-panels-server @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_f8jcm1930j/croot/aext-panels-server_1746552964188/work
# ...

# %%
pip freeze
# Out:
# aext-assistant @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_d5fxz3l2ix/croot/aext-assistant_1746560160060/work
# aext-assistant-server @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_1emcn1_yt0/croot/aext-assistant-server_1746552985810/work
# aext-core @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_2eg8ig5bzd/croot/aext-core_1746546095117/work
# aext-core-server @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_1eo4dumd8o/croot/aext-core-server_1746542359934/work
# aext-panels @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_88neb0jwio/croot/aext-panels_1746560092300/work
# aext-panels-server @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_f8jcm1930j/croot/aext-panels-server_1746552964188/work
# ...

# %% [markdown]
# - all pip(Pip installs packages) commands we can do
#       - in jupiter notebook
#       - in anaconda prompt ( we called this as terminal)
# - Recommended approach is user **terminal**
#
# - while you are installing the packages make sure **internet should be connected **
#
# - if you dont connect internet or your internet is week we will get **http error**
#
# - the command always starts with: **pip install <package name>**

# %%
import streamlit

# %%
import flask

# %%
import cv2

# %% [markdown]
# no module is name : cv2
#
# pip install cv2
# pip install flask

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import cv2

# %%
# help(cv2)
# Out:
# Help on package cv2:
#
# NAME
#     cv2 - OpenCV Python binary extension loader
#
# PACKAGE CONTENTS
#     config
#     config-3
#     cv2
#     data (package)
#     gapi (package)
#     load_config_py2
#     load_config_py3
#     mat_wrapper (package)
#     misc (package)
#     typing (package)
#     utils (package)
#     version
#
# SUBMODULES
#     Error
#     aruco
#     barcode
#     cuda
#     detail
#     dnn
#     fisheye
#     flann
#     ipp
#     ml
#     ocl
#     ogl
#     parallel
#     samples
#     segmentation
#     videoio_registry
#
# DATA
#     __all__ = []
#
# VERSION
#     4.12.0
#
# FILE
#     /opt/anaconda3/lib/python3.13/site-packages/cv2/__init__.py
