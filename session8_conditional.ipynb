# %%
print(1)
# Out:
# 1

# %%
print(1)
print(2)
#--------------------
if 10>0:
    print('Hello')
    if True:
        print('good')
else:
    print('Bye')
#------------------------
print(3)
pr
# Out:
# 1
# 2
# Hello
# good
# 3

# %%
print(1)
print(2)
#-----------------------
if 10>0:
    print('Hello')
    if False:
        print('good')
    else:
        print('ávg')
else:
        print('Bye')
        if 2==2:
            print('Okay')
# Out:
# 1
# 2
# Hello
# ávg

# %%
#WAP ask the user take a number and find it is even or odd
n=eval(input('enter a no: '))
if n%2==0:
    print('even no')
else:
    print('odd n')
# Out:
# enter a no:  1.2
# odd n

# %%
import random;
n=random.randint(1,100)

print(f'number : {n}')
if n%2==0:
    print('even')
else:
    print('odd')

# how to take input numbers
# hardcoded
# from keyword
# random lib
# Out:
# number : 30
# even

# %%
#Wap ask the user enter a number
#  print positive if it is greater than zero
#  otherwise print negative 
# idea:
# num=eval()
# if <con>: 

n=eval(input('enter  a  number: '))
print(f'number is {n} is ')
if n>0:
    print('postive')
else: 
    if n==0:
        print('zero')
    else:
        print('negative')
# Out:
# enter  a  number:  0
# number is 0 is
# zero

# %%
#Q5: casino play

#wap ask the number enter a muber n1
#get a ramdon number between 1 to 10 n2
# if n1 equal to n2
# print won
# other wise print katam

n1=eval(input('enter a no'))
n2=random.randint(1,10)

if n1==n2:
    print('won')
else:
    print('katam')
# Out:
# enter a no 2
# won

# %%
original_pwd="omkar123"
user_pwd=input('enter you pwd')
if original_pwd==user_pwd:
    print('successfully login')
else:
    print('try again')
# Out:
# enter you pwd omkar123
# successfully login

# %%
course=input('enter course name:')
inst=input('enter institute name:')

if course=='Data Science' and inst=='NareshIT':
             print('life is secure')
else:
    print('katam zindgi')
# Out:
# enter course name: Data Science
# enter institute name: NareshIT
# life is secure

# %%
'Data Science'.lower()=='data science'.lower()
# Out:
# True

# %%
'Data sciencE'.lower()=='data Science'.lower()
# Out:
# True

# %%
str1='Data science'
str2='data SciencE'

if str1.lower()==str2.lower():
    print(f' {str1} and {str2} are equal')

newStr1=str1.replace(' ','');
newStr2=str2.replace(' ', '');
print(f' transform results: {newStr1} and {newStr2}')

if newStr1.lower()==newStr2.lower():
     print(f' {str1} and {str2} are equal')
# Out:
#  Data science and data SciencE are equal
#  transform results: Datascience and dataSciencE
#  Data science and data SciencE are equal

# %%
n=eval(input('enter  a number:'))
if n==1:
    print('one')
elif n==2:
         print('two')
elif n==3:
     print('three')
else:
    print('valid number')
# Out:
# enter  a number: a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 n=eval(input('enter  a number:'))
#       2 if n==1:
#       3     print('one')
#
# File <string>:1
#
# NameError: name 'a' is not defined

# %%
num=eval(input('enter a number:'))
if num>10:
    print(f'{n} greater than 10')
elif num>5:
    print(f'{n} greater than 5')
elif num>3:
    print(f'{n} greater than 3')
else:
    print('entered no is valid number')
# Out:
# enter a number: 10
# 10 greater than 5

# %%
num=eval(input('enter a number'))
if num>10:
    print(f'{num} greater than 10')
if num>5:
    print(f'{num} greater than 5')
if num>3:
    print(f'{num} greater than 3')
else:
    print('entered number is a valid number')
# Out:
# enter a number 10
# 10 greater than 5
# 10 greater than 3

# %%
marks=eval(input('enter marks: '))
if marks>100:
    print('max marks allowed is 100')
    marks=eval(input('re-enter marks: '))
if marks>75:
    print('A grade')
elif marks>60:
    print('B grade')
elif marks>45:
        print('C grade')
elif marks>35:
        print('D grade')
else:
    print('Re-try ')
# Out:
# enter marks:  100
# A grade

# %%
age=eval(input('enter a age'))
if age>100:
    print('lucky person')
elif age>60:
    print('Senior citizen')
elif age>30:
    print('Middle Age')
elif age>20:
    print('Youth')
elif age>13:
    print('Teenage')
else:
    print('kid')
# Out:
# enter a age 50
# Middle Age

# %%
100
