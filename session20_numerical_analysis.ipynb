# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import seaborn as sns
# import pandas as pd

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path=r"/Users/suniltomar/Desktop/workspace/nareshit_ds/DS_app1/Visadataset.csv"
visa_df=pd.read_csv(file_path)


cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
file_path="C:/"

visa_df=pd

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       1 file_path="C:/"
#       3 visa_df=pd
# ----> 5 cat=visa_df.select_dtypes(include='object').columns
#       6 num=visa_df.select_dtypes()
#
# AttributeError: module 'pandas' has no attribute 'select_dtypes'

# %%
num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 num
#
# NameError: name 'num' is not defined

# %%
pwage=visa_df['']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pwage=visa_df['']
#
# TypeError: 'module' object is not subscriptable

# %%
min(pwage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 min(pwage)
#
# NameError: name 'pwage' is not defined

# %%
np.min(pwage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 np.min(pwage)
#
# NameError: name 'pwage' is not defined

# %%
pwage.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pwage.min()
#
# NameError: name 'pwage' is not defined

# %% [markdown]
# - operation

# %%
np.max(pwage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 np.max(pwage)
#
# NameError: name 'pwage' is not defined

# %%
np.mean(pwage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 np.mean(pwage)
#
# NameError: name 'pwage' is not defined

# %%
np.median(pwage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.median(pwage)
#
# NameError: name 'pwage' is not defined

# %%
len(pwage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 len(pwage)
#
# NameError: name 'pwage' is not defined

# %%
# 25 percentile
np.percentile(pwage,
              25
             )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # 25 percentile
# ----> 2 np.percentile(pwage,
#       3               25
#       4              )
#
# NameError: name 'pwage' is not defined

# %%
np.quantile(pwage, 0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 np.quantile(pwage, 0.25)
#
# NameError: name 'pwage' is not defined

# %%
# take empty list

Count=pwage.count()
Min=np.min(pwage)
p_25=np.percentile(pwage,25)
# Mean=np.quantile(pwage,0.25)
Mean=np.mean(pwage)
Median=np.median(pwage)
p_50=np.percentile(pwage,50)
p_75=np.percentile(pwage, 75)
Max=np.max(pwage)
metrics=[Count, Min, p_25, Mean, Median, p_50, p_75, Max]
ID=['count', 'min', '25%', 'mean',
    'median', '50%', '75%', 'Max']

l.append(metrics)

pd.DataFrame(metrics, index=ID, columns=['pervailing_wage'])

#create DataFrame after forloop
# columns= num
emptyList=[]
pd.DataFrame(<empty list>, index=ID, columns=<nums>)

#
# Out:
#   Cell In[17], line 23
#     pd.DataFrame(<empty list>, index=ID, columns=<nums>)
#                  ^
# SyntaxError: invalid syntax

# %%
empWage=[]
Count=empWage.count()
Min=np.min(empWage)
p_25%=np.percentile(empWage, 25)
Mean=np.mean(empWage)
Median=np.median(empWage)
p_50=np.percentile(empWage, 50)
p_75=np.percentile(empWage, 75)
Max=np.max(empWage)
Metric=[Count, Min, p_25, Mean, Median, p_50, p_75, Max]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 empWage=[]
# ----> 2 Count=empWage.count()
#       3 Min=np.min(empWage)
#       4 p_25%=np.percentile(empWage, 25)
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
visa_df.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 visa_df.describe()
#
# AttributeError: module 'pandas' has no attribute 'describe'

# %%
#step1: total data : visadaf[pwage]
#step2: Less than 25p 34015.48
#step3: create a condition
#step4: extract the True values visa_df[con]


pwage=visa_df['prevaliling_wage']
p_25=np.percentile(pwage, 25)
con=pwage<p_25
visa_df[con]
len(visa_df[con])==25480*25/100
# 6370   == 6370
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       1 #step1: total data : visadaf[pwage]
#       2 #step2: Less than 25p 34015.48
#       3 #step3: create a condition
#       4 #step4: extract the True values visa_df[con]
# ----> 7 pwage=visa_df['prevaliling_wage']
#       8 p_25=np.percentile(pwage, 25)
#       9 con=pwage<p_25
#
# TypeError: 'module' object is not subscriptable

# %% [markdown]
# - Imperical Rules - what is this rule?
# -

# %%
wage_data=wage_mean=visa_df=['pervaliing_wage']

wage_mean=visa_df=['pervaliing_wage'].mean()
wage_mean=visa_df=['pervaliing_wage'].std()
lb=wage_mean-1*wage_std
ub=wage_mean+1*wage_std
lb,ub
con1=wage_data>lb
con2=wage_data<ub
con=con1 & con2
len(visa_df[con])


len(visa_df[con])=68*25480/100
# Out:
#   Cell In[21], line 14
#     len(visa_df[con])=68*25480/100
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
68*25480/100
# Out:
# 17326.4

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 wage_data=visa_df['prevailing_wage']
#       2 wage_mean=visa_df['prevailing_wage'].mean()
#       3 wage_std=visa_df['prevailing_wage'].std()
#
# TypeError: 'module' object is not subscriptable

# %% [markdown]
# ***emerival rule valid for normal distribution***
#
# ***the above analysis conculded, data does not follow normally***

# %% [markdown]
# - Histogram

# %%
wage_data=visa_df['prevalaing_wage']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 wage_data=visa_df['prevalaing_wage']
#
# TypeError: 'module' object is not subscriptable

# %%
#

# %% [markdown]
# - we understand the **percentile**
# - we explore about **emperical rule**
# - then **emperical rule** failed
# - that means the data does not follow **normal distribution**
# - we also checked with **histogram plot**
# - histogram plot also supports out research: data does not follow **normallity**
# - it gas right skew, so that some **outliers** present
# - we need to visualise those outliers by using **BOXPLOT**

# %%
plt.boxplot(wage_data, vert=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.boxplot(wage_data, vert=False)
#       2 plt.show()
#
# NameError: name 'wage_data' is not defined

# %%
# step-1: q1
# step-2: q2
# step-3: q3
# step-4: iqr=q3-q1
# step-5: lb=q1-1.5*iqr
# step-6: ub=q3+1.5*iqr
# step-7: con1
# step-8: con2
# step-9: con
# step-10: get the count

# %%
q1= np.percentile(wage_data, 25)
q2= np.percentile(wage_data, 50)
q3= np.percentile(wage_data, 75)

iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3= con1 | con2
len(visa_df[con3])

outliers_df=visa_df[con3]
outliers_list=outliers_df['prevailing_wage'].values.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 q1= np.percentile(wage_data, 25)
#       2 q2= np.percentile(wage_data, 50)
#       3 q3= np.percentile(wage_data, 75)
#
# NameError: name 'wage_data' is not defined

# %%
# i want to call the each observation of wage data
# if that observation will availble in this 427 values
# the that observation will replace by median
# otherwise that observation will be available as it is

wage_median=visa_df['prevailing_wage'].median()
wage_data=visa_df['prevailing_wage']
new_wage_data=[]
for i in wage_data:
    if i in outliers_list:
        #new wage data append with median
        new_wage_data.append(wage_median)
    else:
        # new wage data append with i
         new_wage_data.append(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 6
#       1 # i want to call the each observation of wage data
#       2 # if that observation will availble in this 427 values
#       3 # the that observation will replace by median
#       4 # otherwise that observation will be available as it is
# ----> 6 wage_median=visa_df['prevailing_wage'].median()
#       7 wage_data=visa_df['prevailing_wage']
#       8 new_wage_data=[]
#
# TypeError: 'module' object is not subscriptable

# %%
plt.subplot(2,2,1)
plt.hist(wage_data)

plt.subplot(2,2,2)
plt.hist(new_wage_data)

plt.subplot(2,2,3)
plt.hist(wage_data, vert=False)

plt.subplot(2,2,4)
plt.hist(new_wage_data,  vert=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 plt.subplot(2,2,1)
# ----> 2 plt.hist(wage_data)
#       4 plt.subplot(2,2,2)
#       5 plt.hist(new_wage_data)
#
# NameError: name 'wage_data' is not defined

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)

plt.subplot(2,2,2)
plt.hist(new_wage_data)

plt.subplot(2,2,3)
plt.hist(wage_data, vert=False)

plt.subplot(2,2,4)
plt.hist(new_wage_data,  vert=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 plt.subplot(2,2,1).hist(wage_data)
#       4 plt.subplot(2,2,2)
#       5 plt.hist(new_wage_data)
#
# NameError: name 'wage_data' is not defined

# %% [markdown]
# **Winsoriazation**
# - whatever the outliers less than lb fill with lb
# - whatever the outliers greater than ub fill with ub
# - in numpy we have method **clip**

# %%
# step-1: get the wage data values
# step-2: calculate lb
# step-3: calculate ub
# step-4: check the parameters and apply in numpy np.clip()
# step-5: again implment above visulasization analysis

# %%
wage_data=visa_df['prevailing_wage']

q1=np.percentile(wage_data, 25)
Q2=np.percentile(wage_data, 50)
q3=np.percentile(wage_data, 75)

iqr=q3-q1

lb=q1 - 1.5*iqr
ub=q3 + 1.5*iqr

wage_data_clip=np.clip(wage_data, lb, ub)

# %%
plt.figure
