# %%
# pip install langchain_google_genai

# %%
import langchain_google_genai as genai
import os

# %%
# gemini_api_key=os.getenv('GEMINI_API_KEY')
gemini_api_key='GEMINI_API_KEY'
print(gemini_api_key)
os.environ['GOOGLE_API_KEY']=gemini_api_key
# Out:
# GEMINI_API_KEY

# %% [markdown]
# - we need to see two way
# - class is different and model names differnt
# - different models for different uses cases
# -  in order to access those model we might use different classess
# -  other than Embedding models we have below operations can access by using two classes
#    -  ChatGoogleGenrativeAI
#    -  GoogleGenrativeAI
#
# -  For Embeddings
# -   - GoogleGenerativeAIEmbeddings
#
#     - **Chat Models**: for conversations
#
#     - **LLM Models**: for text completions
#
#     - **Embedding models**: RAG applications vector search
#
#     - **Multimodel models**: vision and text
#
#     -
