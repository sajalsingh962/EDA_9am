# %% [markdown]
# #Variables

# %% [markdown]
# -
# -
# m

# %%
num1=100
# 100 stored in a varirable num1
num1
# Out:
# 100

# %%
n1=100
n2=200
n3=300
n=n1+n2+n5 #name 'n5' is not denfiend
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 n2=200
#       3 n3=300
# ----> 4 n=n1+n2+n5
#
# NameError: name 'n5' is not defined

# %%
n1=100
n2=200
n3=300

n5=600
n=n1+n2+n5

# %%
n1=100, 200
n1
# Out:
# (100, 200)

# %%
n1,n2=100,200
n1
# Out:
# 100

# %%
n1,n2=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 n1,n2=100
#
# TypeError: cannot unpack non-iterable int object

# %%
NUMBER=100

# %%
NUMBER
# Out:
# 100

# %%
OverflowError
# Out:
# OverflowError

# %%
- Variable are case sensitive 
- Variable can be upper case and also can be lowere case
- Variable should not start with
# Out:
#   Cell In[18], line 1
#     - Variable are case sensitive
#                ^
# SyntaxError: invalid syntax

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/suniltomar'
