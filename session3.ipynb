# %% [markdown]
# #Data type

# %%
int
float
bool
str
complex
range
list
tuple
dict
set
frozenset
bytearray
bytes
memoryview
# Out:
# memoryview

# %%
money=5000.75
type(money)
# Out:
# float

# %%
1e1
# Out:
# 10.0

# %%
1e1, 1e2, 1e3, 1e4, 1e5
# Out:
# (10.0, 100.0, 1000.0, 10000.0, 100000.0)

# %%
print(1e1)
print(1e2)
print(1e3)
# Out:
# 10.0
# 100.0
# 1000.0

# %%
1e+1,1e+2,1e+3
# Out:
# (10.0, 100.0, 1000.0)

# %%
# ML many notations epower
520e-10 #520/10000000000
# Out:
# 5.2e-08

# %%
name='python'
type(name)
# Out:
# str

# %%
city="hyderabad"
city
# Out:
# 'hyderabad'

# %%
# name : single quotes
# city : double quotes
name,city
# Out:
# ('python', 'hyderabad')

# %%
print(name)
# Out:
# python

# %%
print(name, city)
# whenerver we print the answers with out quotes
# Out:
# python hyderabad

# %% [markdown]
# **tripe quotes**
# - triple quotes are used to write multi lines
# - if I want to write an information, I can use **markdown** in jupiter
# - But in Vscode there is No markdown
# - Then I can use triple quotes to convey the information
# - This procedure is called as **doc string **
# - in promot engineering also we will use multiple lines

# %%
"""today im learning python data type
these are very easy"""
# Out:
# 'today im learning python data type\nthese are very easy'

# %%
9.45e-3 # 9.45/1000  0.00945
# Out:
# 0.00945

# %%
name1='çity'
name2="city"
print(name1, name2)
# Out:
# çity city

# %%
'i like 'python''
"i like "python""
# Out:
#   Cell In[5], line 1
#     'i like 'python''
#              ^
# SyntaxError: invalid syntax

# %%
str1='i like "python"'
print(str1)
# Out:
# i like "python"

# %%
str2="i like 'python'"
print(str2)
# Out:
# i like 'python'

# %%
"python
# Out:
#   Cell In[9], line 1
#     "python
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"python'
# Out:
#   Cell In[10], line 1
#     "python'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"python" # No error
'python'# NE
"python # End 
"python'# syntax error
'python" # syntax error
# Out:
#   Cell In[11], line 3
#     "python # End
#     ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# boolean
#
# - True incdicates 1, ON
#
# - False indicates 0, OFF

# %%
true=True
false ='False'
true=100
false=true
True=10
# Out:
#   Cell In[13], line 5
#     True=10
#     ^
# SyntaxError: cannot assign to True

# %%
true=True
type(true)
# Out:
# bool
